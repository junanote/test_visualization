# %% [markdown]
# <a href="https://colab.research.google.com/github/junanote/test_visualization/blob/master/210705_2_%EB%82%A8%EB%B6%81%ED%95%9C%EB%B0%9C%EC%A0%84%EC%A0%84%EB%A0%A5%EB%9F%89_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('남북한발전전력량.xlsx')

# %%
#df.head(3)

# %%
#df.iloc[0:2,0:2]
df_ns = df.iloc[[0,5],2:]

# %%
df_ns
# Out:
#    1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# 0  1077  1186  1310  1444  1650  1847  ...  4969  5096  5171  5220  5281  5404
# 5   277   263   247   221   231   230  ...   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
#df.columns = [,,,,,,,,,,,,]

# %%
df_ns.index =['south','north']
df_ns
# Out:
#        1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# south  1077  1186  1310  1444  1650  1847  ...  4969  5096  5171  5220  5281  5404
# north   277   263   247   221   231   230  ...   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
df_ns.plot()

# %%
df_ns = df_ns.transpose()
df_ns
# Out:
#      south north
# 1990  1077   277
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
type(df_ns)
# Out:
# pandas.core.frame.DataFrame

# %%
#line_plot
df_ns.plot(kind='line')

# %%
type(df_ns)
# Out:
# pandas.core.frame.DataFrame

# %%
#line_plot
df_ns.plot(kind='line')

# %%
#bar_plot
df_ns.plot(kind='bar')

# %%
#barh_plot
df_ns.plot(kind='barh')

# %%
#hist_plot
df_ns.plot(kind='hist')

# %%
#box_plot
df_ns.plot(kind='box')

# %%
#kde_plot
df_ns.plot(kind='kde')

# %%
#density_plot
df_ns.plot(kind='density')

# %%
#area_plot
df_ns.plot(kind='area')
